# %%
import pandas as pd

# %%
testdata = pd.read_parquet("testfeed.parquet")

# %%
testdata.iloc[0]["post"]
# Out:
# {'author': {'associated': {'activity_subscription': {'allow_subscriptions': 'followers',
#     'py_type': 'app.bsky.actor.defs#profileAssociatedActivitySubscription'},
#    'chat': None,
#    'feedgens': None,
#    'labeler': None,
#    'lists': None,
#    'py_type': 'app.bsky.actor.defs#profileAssociated',
#    'starter_packs': None},
#   'avatar': 'https://cdn.bsky.app/img/avatar/plain/did:plc:7bx6ks4hegfffwikddvfiooi/bafkreieb2w3sw6vtqm5eqva5h76g7quxlvscfvtqdf3wjubbrza5dx4uia@jpeg',
#   'created_at': '2023-08-06T20:45:34.450Z',
#   'did': 'did:plc:7bx6ks4hegfffwikddvfiooi',
#   'display_name': 'Eli Sennesh',
#   'handle': 'elisennesh.bsky.social',
#   'labels': array([], dtype=object),
#   'py_type': 'app.bsky.actor.defs#profileViewBasic',
#   'status': None,
#   'verification': None,
#   'viewer': {'activity_subscription': None,
#    'blocked_by': False,
#    'blocking': None,
#    'blocking_by_list': None,
#    'followed_by': None,
# ...

# %%
# next step: parse post
# build digest
